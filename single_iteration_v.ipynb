# %%
from qiskit import QuantumCircuit,QuantumRegister,ClassicalRegister, transpile, Aer, assemble
import numpy as np
from qiskit import QuantumCircuit, transpile, Aer, assemble, execute
from qiskit.visualization import circuit_drawer, plot_histogram
import numpy as np
from numpy import pi
from qiskit.visualization import plot_state_city, plot_bloch_multivector
from qiskit.visualization import plot_state_paulivec, plot_state_hinton
from qiskit.visualization import plot_state_qsphere

# %%
qreg_q = QuantumRegister(5, 'q')
creg_c = ClassicalRegister(5, 'c')
qc = QuantumCircuit(qreg_q, creg_c)
qc.h(3)
qc.t(3)
qc.h(3)
qc.s(3)
qc.x(3)
qc.u(0,0,-pi/2,4)
qc.cx(3,4)
qc.u(-0.2,-0.1,-0.1,4)
qc.cx(3,4)
qc.x(3)
qc.u(0.2,0.1,0.1,4)
qc.u(0,0,pi/2,4)
qc.measure(4,0)
qc.draw('mpl')

# %%
from qiskit_aer import AerSimulator
from qiskit.visualization import plot_histogram
backend=AerSimulator()
job=backend.run(qc)
result=job.result()
count=result.get_counts(qc)
plot_histogram(count)

# %%
backend = Aer.get_backend('statevector_simulator')
result = execute(qc, backend).result()
statevector = result.get_statevector()


plot_state_city(statevector)

# %%
plot_state_qsphere(statevector)

# %%
plot_state_paulivec(statevector)

# %%
plot_bloch_multivector(statevector)

# %%
plot_state_city(statevector, title="My City", color=['black', 'orange'])

# %%
plot_state_paulivec(statevector, title="My Paulivec", color=['purple', 'orange', 'green'])
